# %% [markdown]
# <a href="https://colab.research.google.com/github/EAFIT-BI/Programming-for-Business-in-Accounting-2024-2/blob/main/Indexaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cargamos las librerías
import pandas as pd
import numpy as np

#leemos el archivo
data = pd.read_csv("/content/home_data.csv")

#visualizamos el archivo para corroborar
#visualizamos los últimos 3 registros
data.tail(3)
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 21610           1020        2007
# ...

# %%
#para consultar el tipo básico de datos que tenemos en la tabla
#usamos la función info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
#vamos a cambiar el tipo de dato del id. Actualmente es tipo entero
#y lo cambiaremos a tipo objeto

data = data.astype({'id':'object'})
#visualizamos la información nuevamente para asegurarnos que el cambio se hizo
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  object
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
#un tipo de dato especial es el tipo fecha. Vamos a reemplazar la fecha
#actual por el formato correcto

data['date'] = pd.to_datetime(data['date'], dayfirst = False)

#visualizamos los primeros cinco registros para revisar el cambio

# %%
data.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
# ...

# %% [markdown]
# # Indexación de filas

# %%
#creamos una copia de la tabla actual (no sobreescribimos)
#esta nueva copia tendrá como indice el id
data2 = data.set_index('id').copy()
data2.head()
# Out:
#                  date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520 2014-10-13  221900         3       1.00         1180      5650
# 6414100192 2014-12-09  538000         3       2.25         2570      7242
# 5631500400 2015-02-25  180000         2       1.00          770     10000
# 2487200875 2014-12-09  604000         4       3.00         1960      5000
# 1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520     1.0           0     0          3      7        1180
# 6414100192     2.0           0     0          3      7        2170
# 5631500400     1.0           0     0          3      6         770
# 2487200875     1.0           0     0          5      7        1050
# 1954400510     1.0           0     0          3      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# ...

# %%
#volvemos al índice original
data2.reset_index(inplace = True)
data2.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
# ...

# %%
#volvemos a establecer el índice con el id
data2.set_index('id', inplace = True)
data2.head()
# Out:
#                  date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520 2014-10-13  221900         3       1.00         1180      5650
# 6414100192 2014-12-09  538000         3       2.25         2570      7242
# 5631500400 2015-02-25  180000         2       1.00          770     10000
# 2487200875 2014-12-09  604000         4       3.00         1960      5000
# 1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520     1.0           0     0          3      7        1180
# 6414100192     2.0           0     0          3      7        2170
# 5631500400     1.0           0     0          3      6         770
# 2487200875     1.0           0     0          5      7        1050
# 1954400510     1.0           0     0          3      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# ...

# %% [markdown]
# # Indexación y *slicing* del *DataFrame*
#
# Usualmente, se hacen mediante las funciones `loc`y `iloc`. El primero usa los índices creados por el programador, y el segundo usa el número de fila o filas.

# %%
#miramos el nombre de las columnas de la tabla
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#lo debo hacer cuando no hay ningún índice para las filas
data.index[:3]
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
#esto es lo que llamamos slicing, que es tomar varias filas consecutivas
data.loc[data.index[0]:data.index[3]]
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# ...

# %%
#podemos hacer la misma operación, usando esta vez la función iloc
data.iloc[0:4]
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# ...

# %%
#También podemos acceder al contenido de la tabla
#usando los nombres de las filas y las columnas.
#En las el caso de las columnas, podremos acceder de la
#siguiente manera

data['bedrooms']

# %%
#en el caso que queramos acceder a varias columnas de forma simultánea
#es posible hacerlo siempre en cuendo se pasen como una lista ['id', 'date', 'price']

data[['id', 'date', 'price']]

# %%
#el slicing NUNCA se hace con nombres, porque los
#nombres no tienen orden y eso siempre producirá un error
data['id':'price']

# %%
#podemos acceder a la información de una celda, indicando el número de la fila (índice)
#y el nombre de la columna

data.loc[10, 'bathrooms'] #la casa número 11, número de baños
# Out:
# 2.5

# %%
#igualmente, se puede acceder al mismo registro de la siguiente manera

data['bathrooms'][10]
# Out:
# 2.5

# %%
#El contenido de una celda se puede modificar con loc, pero es
#más recomendable modificarlo con at

data.at[10, 'bathrooms'] = 3

# %%
#vamos a comprobar que el cambió se realizó
data['bathrooms'][10]
# Out:
# 3.0

# %%
#también podemos eliminar columnas completas con el método drop
data.drop('sqft_living15', axis = 1, inplace = True)
#comprobamos que el cambio se hizo
data.head(2)
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_lot15
# 0      1955             0    98178  47.5112 -122.257        5650
# 1      1951          1991    98125  47.7210 -122.319        7639

# %%
#si axis = 0, elimina filas, si axis = 1, elimina columnas,
#para este ejemplo, eliminaremos la tercera fila

data.drop(2, axis = 0, inplace = True)

#visualizamos el cambio
data.head(5)

# %%
data['cualquier cosa'] = 0

# %%
data.head(4)

# %%
#también existe la forma del para eliminar columnas
del data['cualquier cosa']
data.head(4)

# %%
#también podemos hacer filtrado o slicing con operadores lógicos
#por ejemplo, queremos una subtabla con todas las casas que tengan
#más de 4 habitaciones

data[data['bedrooms'] > 4]

# %%
#ahora haremos un filtrado por el precio. Podríamos pensar en filtrar
#las propiedades que tengan un precio entre 200000 dólares y 300000 dólares

filtros = data[(data['price'] >= 200000) & (data['price'] <= 300000) & (data['date'] >= '2015-01-01')]

# %%
filtros.shape[0]
# Out:
# 1202
